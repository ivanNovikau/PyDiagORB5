# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# %matplotlib notebook
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
run main_TCV

# %%
reload()

equ.B_equil(n80_circular)
equ.B_equil(n80_potsc)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
# ******************************
# *** SAFETY FACTOR PROFILES ***
# ******************************
reload()
npr = 2

oo_q_s = {
    'ovars': [
        ['equ-profile', 'q'],
    ]*npr,
    'avrs': [
        ['ts', 'point-t', [0]],
    ]*npr,
    'dds': [n80_circular, n80_potsc],
    'labx': 's',
    'laby': 'q',
#     'leg_pos': 'center right',
    'var_legs1': ['circular'],
    'var_legs2': ['TCV'],
}
common.plot_vars_1d(oo_q_s)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# *******************************
# *** Signals along t at s1 ***
# *******************************
reload()

s1 = 0.953
npr = 2

# oo_t_s1 = {
#     'ovars': [
#         ['nonzonal', 'er_r', 0.0], 
#     ] * npr,
#     'avrs': [
#         ['ts', 'point-s', [s1]],
#     ] * npr,
#     'dds': [dd_current],
#     'flag_semilogy': True,
#     'labx': 't[\omega_{ci}^{-1}]',
#     'laby': 'E_r',
# }
# common.plot_vars_1d(oo_t_s1)

oo_t_s1 = {
    'ovars': [
        ['zonal', 'erbar'], 
    ] * npr,
    'avrs': [
        ['ts', 'point-s', [s1]],
    ] * npr,
    'dds': [n80_circular, n80_potsc],
    'flag_semilogy': True,
    'labx': 't[\omega_{ci}^{-1}]',
    'laby': 'Zonal\ E_r',
}
common.plot_vars_1d(oo_t_s1)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# **********************
# *** ZONAL along ts ***
# **********************
reload()

npr = 1
dd_current = dict(n80_circular)

oo_ts = {
    'ovars': [
        ['zonal', 'erbar'], 
    ] * npr,
    'avrs': [
        ['ts']
    ] * npr,
    'dds': [dd_current],
}

oo_ts.update({
#     't_start': 3e4,
#     's_start': 0.3, 's_end': 0.8,
})

common.plot_vars_2d(oo_ts)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# *********************
# *** ZONAL: FFT 2d ***
# *********************
reload()

dd_current = dict(n80_circular)

oo_fft_2d = {
    'ovars': [
        ['zonal', 'erbar'], 
    ],
    'avrs': [
        ['ts', 'none-']
    ],
    'dds': [dd_current],
    'coord_fft': 't',
    'x_fft_domains': [
        [1.2e4, 4e5]
    ],
    'flag_f2': False,
    'sel_norm': 'wc',
    'w_domain': [1.0e-3, 6e-3],
    'dep_domain': [0.6, 1.0],
    'flag_norm': False,
    'tit_plot': 'FFT:\ Zonal\ E_r',
}
oo_fft_2d.update({
    'flag_gao': True, 'flag_gk_fit': False, 'flag_aug20787': False
})

common.plot_fft_2d(oo_fft_2d)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# *********************************
# *** ZONAL FFT contribution 1d ***
# *********************************
reload()

s1 = 0.953

npr = 2

oo_fft_1d = {
    'ovars': [
        ['zonal', 'erbar'], 
        ['nonzonal', 'er_r', 0.0],
    ],
    'avrs': [
        ['ts', 'point-s', [s1]], 
    ] * npr,
    'dds': [n80_potsc] * npr,
    'x_fft_domains': [
        [1.2e4, 4e5]
    ],
    'flag_f2': False,
    'sel_norm': 'wc',
    'w_domain': [2.0e-3, 5e-3],
    'flag_norm': True, 
    'labx': '\omega[\omega_{ci}]',
    'laby': 'FFT\ at\ s = 0.953',
    'var_legs1': ['Zonal\ E_r'],
    'var_legs2': ['E_r'],
}

common.plot_fft_1d(oo_fft_1d)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
from lib import save_tcv

# %%
mix.reload_module(save_tcv)
save_tcv.save_signals(n80_potsc)
# Out:
# <img src="data:image/png;base64,..." width="1000">
