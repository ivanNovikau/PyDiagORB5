# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# %matplotlib notebook
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
run main_NLED31213

# %%
# **********************
# *** ZONAL along ts ***
# **********************
reload()

npr = 1

oo_ts = {
    'ovars': [
        ['zonal', 'erbar'], 
    ] * npr,
    'avrs': [
        ['ts']
    ] * npr,
    'dds': [nb025_f001_mpr],
#     'var_legs1': ['f = 0.01'],
#     'var_legs2': ['f = 0.05'],
#     'var_legs3': ['f = 0.0949'],
}

oo_ts.update({
#     't_start': 3e4,
#     's_start': 0.3, 's_end': 0.8,
})

common.plot_vars_2d(oo_ts)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# ****************************
# *** ZONAL: along t at s1 ***
# ****************************
reload()

npr = 1

oo_t_s1 = {
    'ovars': [
        ['zonal', 'erbar'],
    ]*npr,
    'avrs': [
        ['ts', 'point-s', [0.60]],
    ]*npr,
    'dds': [nb025_f001_mpr],
    'flag_semilogy': True,
    'stys': ['-', ':', ':', ':'],
    'labx': 't[\omega_{ci}^{-1}]',
#     'var_legs1': ['f = 0.05'],
#     'var_legs2': ['dt=10'],
#     'var_legs3': ['dt=20'],
#     'x_start': 3e4,
}
common.plot_vars_1d(oo_t_s1)

# %%
# ***************************
# *** EGAM: MPR: TOTAL ***
# ***************************
reload()

species_name = 'total'
dd_current = dict(b025_f001_mpr)

# tmin, tmax = 0.4e4, 1.0e4
# gam_w = 2.855e-03

# tmin, tmax = 0.8e4, 1.4e4
# gam_w = 2.853e-03

tmin, tmax = 1.2e4, 2.0e4
gam_w = 2.862e-03

n_samples, min_gam_n_periods = 200, 1
filt_je = None
filt_ef = None
filt_er = None

oo_vars = {
    'sel_species': species_name,
}

oo_wg = {
    # work and calcualtion time domain
    #     't_work': [4.e4, 5.8e4],  # previous
    't_work': [tmin, tmax],  # as in EM
    'flag_naive_t_peaks': False,
    'naive_n_periods': 2,
    'flag_inv_peaks': True,
    'gam-w': gam_w,  # normalization is always [wc]
    # calculate confidence intervals
    'flag_stat': True,
    'n_samples': n_samples,
    'min_gam_n_periods': min_gam_n_periods,
}

oo_plot = {
    't_plot': oo_wg['t_work'],
    'flag_norm': True,
    'flag_semilogy': True,
}

common.MPR_gamma(dd_current, oo_vars, oo_wg, oo_plot)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# All chosen time intervals are unique.
# <img src="data:image/png;base64,..." width="1000">
# velocity domain: \mu = [0.38, 112.36]$
# $ v_{\parallel} = [-14.8, 14.8]
# total: Initial: g[wci] = 1.839e-04
# total: Statistics: g[wci] = 1.714e-04+-1.468e-05

# %%
# ****************************
# *** EGAM: MPR: DEUTERIUM ***
# ****************************
reload()

species_name = 'deuterium'
flag_inv_peaks = False
dd_current = dict(b025_f001_mpr)

# tmin, tmax = 0.8e4, 1.4e4
# gam_w = 2.853e-03

tmin, tmax = 1.2e4, 2.0e4
gam_w = 2.862e-03

n_samples, min_gam_n_periods = 200, 1
filt_je = None
filt_ef = None
filt_er = None

oo_vars = {
    'sel_species': species_name,
}

oo_wg = {
    # work and calcualtion time domain
    #     't_work': [4.e4, 5.8e4],  # previous
    't_work': [tmin, tmax],  # as in EM
    'flag_naive_t_peaks': False,
    'naive_n_periods': 2,
    'flag_inv_peaks': flag_inv_peaks,
    'gam-w': gam_w,  # normalization is always [wc]
    # calculate confidence intervals
    'flag_stat': True,
    'n_samples': n_samples,
    'min_gam_n_periods': min_gam_n_periods,
}

oo_plot = {
    't_plot': oo_wg['t_work'],
    'flag_norm': True,
    'flag_semilogy': True,
}

common.MPR_gamma(dd_current, oo_vars, oo_wg, oo_plot)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# All chosen time intervals are unique.
# <img src="data:image/png;base64,..." width="1000">
# velocity domain: \mu = [0.38, 112.36]$
# $ v_{\parallel} = [-14.8, 14.8]
# deuterium: Initial: g[wci] = -3.903e-04
# deuterium: Statistics: g[wci] = -4.105e-04+-1.885e-05

# %%
# ****************************
# *** EGAM: MPR: DEUTERIUM ***
# ****************************
reload()

species_name = 'fast'
flag_inv_peaks = True
dd_current = dict(b025_f001_mpr)

# tmin, tmax = 0.8e4, 1.4e4
# gam_w = 2.853e-03

tmin, tmax = 1.2e4, 2.0e4
gam_w = 2.862e-03

n_samples, min_gam_n_periods = 200, 1
filt_je = None
filt_ef = None
filt_er = None

oo_vars = {
    'sel_species': species_name,
}

oo_wg = {
    # work and calcualtion time domain
    #     't_work': [4.e4, 5.8e4],  # previous
    't_work': [tmin, tmax],  # as in EM
    'flag_naive_t_peaks': False,
    'naive_n_periods': 2,
    'flag_inv_peaks': flag_inv_peaks,
    'gam-w': gam_w,  # normalization is always [wc]
    # calculate confidence intervals
    'flag_stat': True,
    'n_samples': n_samples,
    'min_gam_n_periods': min_gam_n_periods,
}

oo_plot = {
    't_plot': oo_wg['t_work'],
    'flag_norm': True,
    'flag_semilogy': True,
}

common.MPR_gamma(dd_current, oo_vars, oo_wg, oo_plot)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# All chosen time intervals are unique.
# <img src="data:image/png;base64,..." width="1000">
# velocity domain: \mu = [0.40, 120.86]$
# $ v_{\parallel} = [-13.9, 13.9]
# fast: Initial: g[wci] = 5.742e-04
# fast: Statistics: g[wci] = 5.808e-04+-1.039e-05

# %%
5.569e-04 - 3.838e-04
# Out:
# 0.00017310000000000003
