# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# %matplotlib notebook
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
run main_ITPA.py

# %%
# **********************
# *** ZONAL along ts ***
# **********************
reload()

oo_zonal_ts = {
    'ovars': [
        ['zonal', 'erbar'], 
        ['zonal', 'erbar']
    ],
    'avrs': [
        ['ts'], ['ts']
    ],
    'dds': [dd_es, dd_es_flux],
    'tit_plot': ''
}

oo_zonal_ts.update({
    's_start': 0.2, 's_end': 0.8,
    't_start': 0.5e5
})

common.plot_vars_2d(oo_zonal_ts)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
# ************************
# *** ZONAL,aver. in s ***
# ************************
reload()

s_int1 = [0.4, 0.6]
oo_zonal_s1 = {
    'ovars': [
        ['zonal', 'erbar'], 
        ['zonal', 'erbar']
    ],
    'avrs': [
        ['ts', 'rms-s', [s_int1]], 
        ['ts', 'rms-s', [s_int1]]
    ],
    'dds': [dd_es, dd_es_flux],
    'tit_plot': '',
    'flag_semilogy': True,
    'x_start': 0.5e5,
    'labx': 't[\omega_{ci}^{-1}]',
    'laby': '\overline{E}_r',
    'sel_legs1': 'woVN', 'sel_legs2': 'woVN',
}
common.plot_vars_1d(oo_zonal_s1)
# Out:
# <img src="data:image/png;base64,..." width="1400">

# %%
# *************************
# *** NONZONAL along ts ***
# *************************
reload()

oo_nonzonal_ts = {   
    'avrs': [
        ['ts']
    ],
    'dds': [dd_es_flux],  
    's_start': 0.2, 's_end': 0.8,
    't_start': 0.2e5,
    'tit_plot': ''
}

oo_nonzonal_ts.update({
    'ovars': [
        ['nonzonal', 'phinz', 0.0], 
    ],  
})
common.plot_vars_2d(oo_nonzonal_ts)

oo_nonzonal_ts.update({
    'ovars': [
        ['nonzonal', 'ernz_r', 0.0], 
    ],  
})
common.plot_vars_2d(oo_nonzonal_ts)

oo_nonzonal_ts.update({
    'ovars': [
        ['nonzonal', 'ernz_chi', 0.0], 
    ],  
})
common.plot_vars_2d(oo_nonzonal_ts)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
# ******************************
# *** NONZONAL, aver. in s ***
# ******************************
reload()

# opt_var, laby = 'phinz', '\widetilde{\Phi}_{\chi, \chi = 0}'
# opt_var, laby = 'ernz_r', '\widetilde{E}_{r, \chi = 0}'
opt_var, laby = 'ernz_chi', '\widetilde{E}_{\chi, \chi = 0}'

s_int1 = [0.4, 0.6]
oo_nonzonal_s1 = {
    'ovars': [
        ['nonzonal', opt_var, 0.0], 
        ['nonzonal', opt_var, 0.0]
    ],
    'avrs': [
        ['ts', 'rms-s', [s_int1]], 
        ['ts', 'rms-s', [s_int1]]
    ],
    'dds': [dd_es, dd_es_flux],
    'tit_plot': '',
    'flag_semilogy': True,
    'x_start': 0.1e5,
    'labx': 't[\omega_{ci}^{-1}]',
    'laby': laby,
    'sel_legs1': 'woVN', 'sel_legs2': 'woVN',
}
common.plot_vars_1d(oo_nonzonal_s1)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# *************************
# *** NONZONAL (t, chi) ***
# *************************
reload()

oo_nonzonal_tchi = {  
    'ovars': [
        ['nonzonal', 'phinz', 0.5], 
    ],  
    'avrs': [
        ['tchi']
    ],
    'dds': [dd],  
    't_start': 0.2e5,
    'tit_plot': ''
}
common.plot_vars_2d(oo_nonzonal_tchi)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# *****************************
# *** NONZONAL (chi) at t_1 ***
# *****************************
reload()

oo_nonzonal_chi_t1_s1 = {  
    'opt_var': 'ernz_r',
    's_point': 0.8,
    't_point': 2e5,
    'flag_norm': True
}
itg.plot_chi_max(dd, oo_nonzonal_chi_t1_s1)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# No handles with labels found to put in legend.

# %%
# *******************************
# *** ZONAL vs NONZONAL at s1 ***
# *******************************
reload()

# opt_var_z = 'phibar'
# opt_var_nz = 'phinz'

opt_var_z = 'erbar'
opt_var_nz = 'ernz_r'

# opt_var_z = 'erbar'
# opt_var_nz = 'ernz_chi'

oo_z_nz_s1 = {
    'ovars': [
        ['nonzonal', opt_var_nz, 0.0],
        ['zonal',    opt_var_z ],    
    ],
#     'dds': [dd_es_flux, dd_es_flux],
    'dds': [dd_es_flux, dd_es_flux],
    'tit_plot': '',
    'flag_semilogy': True,
    'x_start': 0.0e5,
    'labx': 't[\omega_{ci}^{-1}]',
    'laby': '',
    'sel_legs1': 'woPr', 'sel_legs2': 'woPr',
}

s_point1 = [0.4]
oo_z_nz_s1.update({
    'avrs': [
        ['ts', 'point-s', s_point1], 
        ['ts', 'point-s', s_point1]
    ],
})
common.plot_vars_1d(oo_z_nz_s1)

s_point2 = [0.5]
oo_z_nz_s1.update({
    'avrs': [
        ['ts', 'point-s', s_point2], 
        ['ts', 'point-s', s_point2]
    ],
})
common.plot_vars_1d(oo_z_nz_s1)

s_point3 = [0.6]
oo_z_nz_s1.update({
    'avrs': [
        ['ts', 'point-s', s_point3], 
        ['ts', 'point-s', s_point3]
    ],
})
common.plot_vars_1d(oo_z_nz_s1)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
# **************************************
# *** TIME EVOLUTION OF T profiles ***
# **************************************
reload()

def func_mod_n_t1(x, data):
    x = x[0:len(x)-1]
    data = data[0:len(data)-1]
    return x, data

t_points = [0.0, 1.9e5, 2.1e5]
oo_evol_T_t1 = {
    'ovars': [
        ['transport', 'T', 'deuterium'], 
    ],
    'dds': [dd_es],
    'avrs': [
        ['ts', 'point-t', t_points],  
    ],
    'labx': 's',
    'tit_plot': '',
    'func_mod': func_mod_n_t1
}
common.plot_vars_1d(oo_evol_T_t1)

oo_evol_T_t1.update({
    'ovars': [
        ['transport', 'T', 'deuterium'], 
    ],
    'dds': [dd_es_flux],
})
common.plot_vars_1d(oo_evol_T_t1)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
# **************************************
# *** TIME EVOLUTION OF n proiles ***
# **************************************
reload()

def func_mod_n_t1(x, data):
    x = x[1:len(x)-1]
    data = data[1:len(data)-1]
    return x, data

t_points = [0.0, 1.9e5, 2.1e5]
oo_evol_n_t1 = {
    'ovars': [
        ['transport', 'n', 'deuterium'], 
    ],
    'dds': [dd_es],
    'avrs': [
        ['ts', 'point-t', t_points],  
    ],
    'labx': 's',
    'tit_plot': '',
    'func_mod': func_mod_n_t1
}
common.plot_vars_1d(oo_evol_n_t1)

oo_evol_n_t1.update({
    'ovars': [
        ['transport', 'n', 'deuterium'], 
    ],
    'dds': [dd_es_flux],
})
common.plot_vars_1d(oo_evol_n_t1)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
# ************************
# *** HEAT, aver. in t ***
# ************************
reload()

t_int1 = [1.25e5, 2e5]
line_t = 't = [{:0.2e}, {:0.2e}]'.format(t_int1[0], t_int1[-1])

oo_heat_t1 = {
    'ovars': [
        ['transport', 'efluxw_rad', 'deuterium'], 
        ['transport', 'efluxw_rad', 'deuterium']
    ],
    'avrs': [
        [ 'ts', 'mean-t', [t_int1] ], 
        [ 'ts', 'mean-t', [t_int1] ]
    ],
    'dds': [dd_es, dd_es_flux],
    'labx': 's',
    'tit_plot': 'deuterium:\ radial\ heat\ flux:\ $\n$ mean_t:\ ' + line_t,
    'sel_legs1': 'Pr', 'sel_legs2': 'Pr',
}

common.plot_vars_1d(oo_heat_t1)
# Out:
# <img src="data:image/png;base64,..." width="1400">

# %%
# ************************
# *** HEAT, aver. in s ***
# ************************
reload()
s_int1 = [0.2, 0.8]
line_s = 's = [{:0.1f}, {:0.1f}]'.format(s_int1[0], s_int1[-1])

oo_heat_s1 = {
    'ovars': [
        ['transport', 'efluxw_rad', 'deuterium'], 
        ['transport', 'efluxw_rad', 'deuterium'],
    ],
    'dds': [dd_es, dd_es_flux],
    'avrs': [
        [ 'ts', 'mean-s', [s_int1] ], 
        [ 'ts', 'mean-s', [s_int1] ], 
    ],
    'labx': 't[\omega_{ci}^{-1}]',
    'tit_plot': 'deuterium:\ radial\ heat\ flux:\ $\n$ mean_s:\ ' + line_s,
    'sel_legs1': 'Pr', 'sel_legs2': 'Pr',
}
common.plot_vars_1d(oo_heat_s1)
# Out:
# <img src="data:image/png;base64,..." width="1400">

# %%
loc = np.array([10, 20, 30])
ids_loc = np.array([2,4,8])

glob = np.array([1, 30, 2])
ids_glob = np.array([3,10,1])

mask_comp = loc > glob
glob_new = np.where(mask_comp, loc, glob)
ids_glob_new = np.where(mask_comp, ids_loc, ids_glob)

# %%
glob_new
# Out:
# array([10, 30, 30])

# %%
ids_glob_new
# Out:
# array([ 2, 10,  8])
