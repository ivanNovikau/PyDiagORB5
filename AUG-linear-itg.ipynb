# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# %matplotlib notebook
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
run main_AUG20787.py

# %%
dd_n10 = dict(dd)

# %%
dd_n30 = dict(dd)

# %%
dd_n60 = dict(dd)

# %%
dd = dict(dd_n30)

# %%
reload()
itg.plot_t(dd, { 's_intervals': [[0.4, 0.6], [0.6, 1.0], [0.0, 1.0]] })
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
reload()
oo_n60 = {'s_intervals': [[0.4, 0.6],     [0.6, 1.0],     [0.0, 1.0]], 
          't_intervals': [[0.0e5, 1.0e5], [0.154e5, 1.0e5], [0.154e5, 1.0e5]],
          'flag_adv': False}
oo_n60 = {'s_intervals': [[0.4, 0.6],     [0.6, 1.0],     [0.0, 1.0]], 
          't_intervals': [[0.0e5, 1.0e5], [0.0e5, 0.154e5], [0.0e5, 0.154e5]],
          'flag_adv': False}

oo_n30 = {'s_intervals': [[0.4, 0.6],     [0.6, 1.0],     [0.0, 1.0]], 
          't_intervals': [[0.0e5, 1.0e5], [0.0e5, 1.0e5], [0.0e5, 1.0e5]],
          'flag_adv': False}

# oo_n10 = {'s_intervals': [[0.4, 0.6],     [0.6, 1.0],     [0.0, 1.0]], 
#           't_intervals': [[0.0e5, 1.0e5], [0.0e5, 1.0e5], [0.0e5, 1.0e5]],
#           'filters': [{'sel_filt': 'rough', 'w_interval': [4.0e-4, 1.2e-3]}, 
#                       None, 
#                       None
#                      ],                     
#           'flag_adv': False}
oo_n10 = {'s_intervals': [[0.4, 0.6],     [0.6, 1.0],     [0.0, 1.0]], 
          't_intervals': [[0.0e5, 1.0e5], [0.0e5, 1.0e5], [0.0e5, 1.0e5]],
          'filters': [{'sel_filt': 'smooth', 'wind': 15}, 
                      {'sel_filt': 'smooth', 'wind': 15}, 
                      {'sel_filt': 'smooth', 'wind': 15}
                     ],                     
          'flag_adv': False}
# oo_n10 = {'s_intervals': [[0.4, 0.6],     [0.6, 1.0],     [0.0, 1.0]], 
#           't_intervals': [[0.4e5, 1.0e5], [0.0e5, 1.0e5], [0.0e5, 1.0e5]],
#           'filters': [{'sel_filt': 'fft_smooth', 'wind': 15, 'w_interval': [1.2e-4, 3.0e-3]}, 
#                       None, 
#                       None
#                      ],                     
#           'flag_adv': False}


itg.calc_gamma_chi0(dd, oo_n10)
del oo_n60, oo_n30, oo_n10
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# --- Estimation ---
# E -> *** s = [0.400, 0.404]:\ t = [0.0e+00, 1.0e+05] ***
# E -> w[wci] = 7.620e-04
# E -> g[wci] = 4.874e-05
# E -> *** s = [0.601, 1.000]:\ t = [0.0e+00, 1.0e+05] ***
# E -> w[wci] = 1.609e-04
# E -> g[wci] = 1.062e-04
# E -> *** s = [0.000, 1.000]:\ t = [0.0e+00, 1.0e+05] ***
# E -> w[wci] = 1.614e-04
# E -> g[wci] = 1.111e-04

# %%
reload()
itg.smooth_demo2()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
xx = [1,2,3,4]
yy = [10, 20, 30, 40]
for (x1, y1) in (xx, yy):
    print('x, y = {:d}, {:d}'.format(x1,y1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-c91ccc987330> in <module>
#       1 xx = [1,2,3,4]
#       2 yy = [10, 20, 30, 40]
# ----> 3 for (x1, y1) in (xx, yy):
#       4     print('x, y = {:d}, {:d}'.format(x1,y1))
#
# ValueError: too many values to unpack (expected 2)

# %%
from ip_projects import aug_linear_scan_n

# %%
mix.reload_module(aug_linear_scan_n)
aug_linear_scan_n.aug_scan_n()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
