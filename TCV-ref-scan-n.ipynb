# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# %matplotlib notebook
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
run main_TCV.py

# %%
dd_NL = dict(dd)

# %%
dd_L = dict(dd)

# %%
reload()
equ.q_prof(dd)
equ.nT_profs(dd)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
reload()
zf.fft_gam_2d(dd_NL, {'sel_norm': 'csa', 'sel_cmp': 'jet',
                    'w_start': 0.5e-1, 'w_end': 1, 
                   's_start': 0.5, 
                  't_start': 0.5e5})
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
reload()
zf.time_evol_st(dd, {'s_start': 0.4, 's_end': 0.99, 't_start': 1.5e5, 't_end': 3.e5})
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
reload()
zf.efluxw_rad_2d('deuterium', dd, {'w_start': 0.5e-1, 'w_end': 1, 
                                   's_start': 0.3, 
                                   't_start': 5e4, 
                                   't_av_start': 5e4,
                                   'ns_av': 2, 
                                   's_av1_start': 0.3, 's_av1_end': 0.6, 
                                   's_av2_start': 0.6, 's_av2_end': 1.0})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f9a707d46e6d> in <module>
# ----> 1 reload()
#       2 zf.efluxw_rad_2d('deuterium', dd, {'w_start': 0.5e-1, 'w_end': 1,
#       3                                    's_start': 0.3,
#       4                                    't_start': 5e4,
#       5                                    't_av_start': 5e4,
#
# NameError: name 'reload' is not defined

# %%
reload()
zf.heat_vorticity('deuterium', dd, {'t_start': 1.5e5, 't_end': 2.e5,
                                    'ns_av': 2, 
                                    's_av1_heat_start':   0.6, 's_av1_heat_end':   1.0,
                                    's_av1_vorbar_start': 0.6, 's_av1_vorbar_end': 1.0,
                                    's_av2_heat_start':   0.3, 's_av2_heat_end':   0.6, 
                                    's_av2_vorbar_start': 0.6, 's_av2_vorbar_end': 1.0,})
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
# Save data from a linear simulation dd_L
reload()
zf.wg_s(dd_L, {'sel_norm': 'csa', 's_start': 0.8, 'flag_save': True, 'save_name': 'lin-n0'})
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
# Save data from a linear simulation dd_L
reload()
oo_71 = {'sel_norm': 'csa', 's_start': 0.7, 's_end': 1.0, 't_start': 1.5e3, 't_end': 5e3, 
         'flag_save': True, 'save_name': 'lin_n0_k20'}
zf.wg_s(dd_L, oo_71)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
# Compare linear and nln-linear simulations
reload()
zf.fft_gam_2d(dd_NL, {'sel_norm': 'csa', 'sel_cmp': 'jet',
                'w_start': 0.5e-1, 'w_end': 1, 
                's_start': 0.5, 
                't_start': 0.5e5,
                'curves_to_load': dd_L['saved_data']['lin_n0_k20-w']})
#                 'curves_to_load': dd_L['saved_data']['lin_n0_k2-w']})
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
