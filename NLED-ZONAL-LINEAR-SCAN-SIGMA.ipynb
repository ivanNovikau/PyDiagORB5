# %%
# ***********************************************************
# SCAN ON GAUSSIAN WIDTH: DIRECT and MPR DIAGNOSTIC
# ***********************************************************
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# %matplotlib notebook
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
run main_NLED31213

# %%
# *******************
# *** PLOT: (t,s) ***
# *******************
reload()

oo_equ = {
    'ovars': [
        ['equ-profile', 'n-equ', 'fast'], 
    ] * 4,
    'avrs': [
        ['ts', 'point-t', [0]]
    ] * 4,
#     'dds': [b025_f001_w005, b025_f001, b025_f001_w015, b025_f001_w020],
    'dds': [b025_f009_w005, b025_f009, b025_f009_w015, b025_f009_w020],
#     'var_legs1': ['f = 0.01'],
}
common.plot_vars_1d(oo_equ)

oo_equ = {
    'ovars': [
        ['equ-profile', 'n-equ', 'electrons'], 
    ] * 4,
    'avrs': [
        ['ts', 'point-t', [0]]
    ] * 4,
#     'dds': [b025_f001_w005, b025_f001, b025_f001_w015, b025_f001_w020],
    'dds': [b025_f009_w005, b025_f009, b025_f009_w015, b025_f009_w020],
#     'var_legs1': ['f = 0.01'],
}
common.plot_vars_1d(oo_equ)

oo_equ = {
    'ovars': [
        ['equ-profile', 'n-equ', 'deuterium'], 
    ] * 4,
    'avrs': [
        ['ts', 'point-t', [0]]
    ] * 4,
#     'dds': [b025_f001_w005, b025_f001, b025_f001_w015, b025_f001_w020],
    'dds': [b025_f009_w005, b025_f009, b025_f009_w015, b025_f009_w020],
#     'var_legs1': ['f = 0.01'],
}
common.plot_vars_1d(oo_equ)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
# *******************
# *** PLOT: (t,s) ***
# *******************
reload()

npr = 4

oo_ts = {
    'ovars': [
        ['zonal', 'erbar'], 
    ] * npr,
    'avrs': [
        ['ts']
    ] * npr,
#     'dds': [b025_f001_w005, b025_f001, b025_f001_w015, b025_f001_w020],
    'dds': [b025_f009_w005, b025_f009, b025_f009_w015, b025_f009_w020],
#     'var_legs1': ['f = 0.01'],
}

oo_ts.update({
#      't_start': 6e4,
#     't_end': 6.3e4,
#      's_start': 0.4, 's_end': 0.7,
})

common.plot_vars_2d(oo_ts)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
# ***********************
# *** PLOT: (t) at s1 ***
# ***********************
reload()

# # Cases with f = 0.01
# oo_t_s1 = {
#     'ovars': [
#         ['zonal', 'erbar'],
#     ]*4,
#     'avrs': [
#         ['ts', 'point-s', [0.50]],
#         ['ts', 'point-s', [0.49]],
#         ['ts', 'point-s', [0.49]],
#         ['ts', 'point-s', [0.39]],
#     ],
#     'dds': [b025_f001_w005, b025_f001, b025_f001_w015, b025_f001_w020],
#     'flag_semilogy': True,
#     'stys': ['-', '-', '-', '-'],
#     'labx': 't[\omega_{ci}^{-1}]',
#     'x_start': 1e4, 
# }
# common.plot_vars_1d(oo_t_s1)

# Cases with f = 0.09
oo_t_s1 = {
    'ovars': [
        ['zonal', 'erbar'],
    ]*4,
    'avrs': [
        ['ts', 'point-s', [0.54]],
        ['ts', 'point-s', [0.58]],
        ['ts', 'point-s', [0.60]],
        ['ts', 'point-s', [0.51]],
    ],
    'dds': [b025_f009_w005, b025_f009, b025_f009_w015, b025_f009_w020],
    'flag_semilogy': True,
    'stys': ['-', '-', '-', '-'],
    'labx': 't[\omega_{ci}^{-1}]',
    'x_start': 1e4, 
}
common.plot_vars_1d(oo_t_s1)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# ***********************************************************
# *** ES SIM: DIRECT METHOD: FIND FRQUENCY and GAMMA (s1) ***
# ***********************************************************
reload()

# dd_current, s1 = dict(b025_f001_w005), 0.50
# dd_current, s1 = dict(b025_f001), 0.49
# dd_current, s1 = dict(b025_f001_w015), 0.49
# dd_current, s1 = dict(b025_f001_w020), 0.39

# dd_current, s1 = dict(b025_f009_w005), 0.54
# dd_current, s1 = dict(b025_f009), 0.58
# dd_current, s1 = dict(b025_f009_w015), 0.60
dd_current, s1 = dict(b025_f009_w020), 0.51

tmin, tmax = 6.5e4, 8e4  # for f=0.09
# tmin, tmax = 3e4, 8e4

filt_global = None
min_n_peaks, threshold_w, threshold_g = 8, 0.1, 0.1
n_samples = 300
sel_norm = 'wc'

oo_var = {
    'ovars': [['zonal', 'erbar']],
    'avrs': [['ts', 'point-s', [s1]]],
    'dds': [dd_current],
#     'sel_legs1': 'woPr',
}

oo_wg = {
    # BASIC
    't_work': [tmin, tmax], 
    'flag_two_stages': True,
#     'sel_norm': 'vt',
    # FILTERING
    'filt_global': filt_global,
    # STATISTICS
    'flag_stat':   True,
    'n_samples':   n_samples,
    'min_n_peaks': min_n_peaks,
    'threshold_w': threshold_w,
    'threshold_g': threshold_g,
    'sel_norm': sel_norm,
}

oo_plot = {
#     't_plot': [0.15e4, 1.5e4],
    'flag_norm': True,
    'flag_semilogy': True
}

common.calc_wg(oo_var, oo_wg, oo_plot)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# --- NAIVE CALCULATION ---
# - GAMMA: ESTIMATION -
# prel. w[wci] = 2.591e-03
# g[wci] = 3.437e-04 +- 2.817e-06
# - GAMMA: NL FITTING -
# prel. w[wci] = 2.608e-03 +- inf
# g[wci] = 3.336e-04 +- inf
# - FREQUENCY: ESTIMATION -
# w[wci] = 2.591e-03
# (g_real - g_num)[wci] = 1.000e-05 +- 3.276e-06
# - FREQUENCY: NL FITTING -
# w[wci] = 2.591e-03 +- 3.270e-07
# (g_real - g_num)[wci] = 8.898e-06 +- 3.236e-07
# All chosen time intervals are unique.
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# --- STATISTICS ---
# ...

# %%
from ip_projects import NLED_scans

# %%
# **********************
# *** SCAN ON F_PART ***
# **********************
mix.reload_module(NLED_scans)
NLED_scans.scan_sigma_rho025({'sel_norm': 'khz', 'dd': b025_f001})
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
