# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# %matplotlib notebook
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
run main_TCV

# %%
reload()
# oo_n58 = {'s_intervals': [[0.4, 0.6],     [0.6, 1.0],     [0.0, 1.0]], 
#           't_intervals': [[0.0e5, 2.0e5], [0.154e5, 2.0e5], [0.154e5, 2.0e5]],
#           'filters': [{'sel_filt': 'smooth', 'wind': 3}, 
#                       {'sel_filt': 'smooth', 'wind': 5}, 
#                       {'sel_filt': 'smooth', 'wind':15}
#                      ], 
#           'flag_adv': False}
oo_n62 = {'s_intervals': [[0.4, 0.6],     [0.6, 1.0],     [0.0, 1.0]], 
          't_intervals': [[0.154e5, 2.0e5], [0.154e5, 2.0e5], [0.154e5, 2.0e5]],
          'filters': [{'sel_filt': 'smooth', 'wind': 3}, 
                      {'sel_filt': 'smooth', 'wind': 5}, 
                      {'sel_filt': 'smooth', 'wind':15}
                     ], 
          'flag_adv': False}
itg.calc_gamma_chi0(dd, oo_n62)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# --- Estimation ---
# E -> *** s = [0.402, 0.598]:\ t = [1.5e+04, 1.0e+05] ***
# E -> w[wci] = 1.669e-02
# E -> g[wci] = 1.825e-03
# E -> *** s = [0.602, 1.000]:\ t = [1.5e+04, 1.0e+05] ***
# E -> w[wci] = 8.314e-04
# E -> g[wci] = 1.823e-03
# E -> *** s = [0.000, 1.000]:\ t = [1.5e+04, 1.0e+05] ***
# E -> w[wci] = 8.319e-04
# E -> g[wci] = 1.824e-03

# %%
reload()
oon = {'sel_norm': 'wc',
          's_start': 0.0,     's_end': 1.0, 
          't_start': 0.154e5, 't_end': 2.0e5,
          'filter_g': {'sel_filt': 'smooth', 'wind': 3, 'x_start': 0.1e5}, 
          'filter_w': {'sel_filt': 'smooth', 'wind': 3, 'x_start': 0.1e5}
         }
itg.calc_wg(dd, oon)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# --- Estimation ---
# *** Growth rate: s = [0.000, 1.000]:\ t[1/wc] = [1.540e+04, 1.000e+05] ***
# E -> g[wci] = 1.823e-03
# *** Frequency: s = [0.000, 1.000]:\ t[1/wc] = [0.000e+00, 1.000e+04] ***
# E -> w[wci] = 1.274e-03

# %%
from ip_projects import linear_scans_n
import Mix as mix

# %%
mix.reload_module(linear_scans_n)
linear_scans_n.tcv_scan_n()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
