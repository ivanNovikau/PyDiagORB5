# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# %matplotlib notebook
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
run main_TCV

# %%
reload()
oon = {'sel_norm': 'wc',
          's_start': 0.0,     's_end': 1.0, 
          't_start': 0.154e4, 't_end': 2.0e5,
          'filter_g': {'sel_filt': 'smooth', 'wind': 5, 'x_start': 0.1e5}, 
          'filter_w': {'sel_filt': 'smooth', 'wind': 5, 'x_start': 0.1e5},
           'w_fft': {'n_max': 3}
         }
itg.calc_wg(dd, oon)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# --- Estimation ---
# *** Growth rate: s = [0.000, 1.000]:\ t[1/wc] = [1.000e+04, 1.000e+05] ***
# E -> g[wci] = 1.146e-03
# *** Frequency: s = [0.000, 1.000]:\ t[1/wc] = [1.000e+04, 1.000e+05] ***
# E -> w[wci] = 1.460e-03
# w_fft(id_max = 0) = 1.465e-03,   max(id_max = 0) = 8.796e-10
# w_fft(id_max = 1) = 1.744e-03,   max(id_max = 1) = 8.704e-11
# w_fft(id_max = 2) = 1.954e-03,   max(id_max = 2) = 5.115e-11

# %%
# **************************************
# *** PHINZ along chi ******************
# **************************************
reload()
oo_phinz_chi = {
    'opt_var': 'phinz',
    's_point': 0.3,
    't_points': [1.0e4, 1.1e4],
    'flag_norm': True,
    'flag_max': True
}
itg.plot_chi_t1(dd, oo_phinz_chi)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
from ip_projects import linear_scans_n
import Mix as mix

# %%
mix.reload_module(linear_scans_n)
linear_scans_n.tcv_scan_n({'sel_norm': 'csa', 'dd_tcv': dd})
# Out:
# <img src="data:image/png;base64,..." width="1400">
# <img src="data:image/png;base64,..." width="1400">
# <img src="data:image/png;base64,..." width="1400">
# <img src="data:image/png;base64,..." width="1400">

# %%
t11 = 5249
t22 = 98699
west  = 2*np.pi / (2 * (t22 - t11))
print(west)
# Out:
# 3.3617898914818544e-05

# %%
48*3
# Out:
# 144

# %%
xx = np.array([[1.2, 3.42, 5.42], [20, 10, 0]])

# %%
xx.argmax(axis=1)
# Out:
# array([2, 0], dtype=int64)

# %%
ii = np.array([0, 10, 20 ,30 ,40])
ii[[1,1,2,0]]
# Out:
# array([10, 10, 20,  0])
