# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
run ./main_ITG.py

# %%
dd = prepare_data({}, path_sim)

# %%
reload()

# %%
# %matplotlib notebook

# %%
itg.plot_schi(dd, 1e4, {'s_start': 0, 's_end': 1})
itg.plot_rz(dd, 1e3, {'rr_start': 0.4, 'rr_end': 0.8})
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
itg.plot_schi_max_along_chi(dd, 1e5, {})
itg.plot_rz_max_along_chi(dd, 1e5, {})
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
itg.calc_gamma_chi0(dd, 0.4, 0.8, 0.0, oo={'t_start': 0.0, 't_end': 6e4})
# Out:
# <div id="905da871-5168-4e0f-9279-ba09babe147a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("905da871-5168-4e0f-9279-ba09babe147a")) {
# ...

# %%
reload()
itg.calc_gamma_chimax(dd, 0.4, 0.8, oo={'t_start': 0.0, 't_end': 6e4})
# Out:
# <div id="8698edc7-56d2-461d-8f20-7e355b007cb7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("8698edc7-56d2-461d-8f20-7e355b007cb7")) {
# ...
