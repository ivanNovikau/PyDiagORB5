# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# %matplotlib notebook
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
run main_NLED31213.py

# %%
reload()
equ.q_prof(dd)
equ.nT_profs(dd)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
# ************************************************
# *** JDOTE-es along (vpar, mu), aver. in time ***
# ************************************************
reload()

t_int_jdote = [2.995e4, 3.945e4]
t_int_jdote = [2.7564e4, 3.955e4]

oo_jdote_es_vpar_mu = {
    'avrs': [
        ['vparmu']
    ],
    'dds': [dd],
}

oo_jdote_es_vpar_mu.update({
    'ovars': [
        ['mpr', 'jdote_es-mean-t', 'deuterium', t_int_jdote],  
    ],
    'tit_plot': 'deuterium:\ <J \cdot E>_{t}'
})
common.plot_vars_2d(oo_jdote_es_vpar_mu)

oo_jdote_es_vpar_mu.update({
    'ovars': [
        ['mpr', 'jdote_es-mean-t', 'electrons', t_int_jdote],  
    ],
    'tit_plot': 'electrons:\ <J \cdot E>_{t}'
})
common.plot_vars_2d(oo_jdote_es_vpar_mu)

oo_jdote_es_vpar_mu.update({
    'ovars': [
        ['mpr', 'jdote_es-mean-t', 'fast', t_int_jdote],  
    ],
    'tit_plot': 'fast:\ <J \cdot E>_{t}'
})
common.plot_vars_2d(oo_jdote_es_vpar_mu)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
# *******************
# *** ZONAL in s1 ***
# *******************
reload()

oo_zonal_s1 = {
    'ovars': [
        ['zonal', 'erbar'], 
    ],
    'avrs': [
        ['ts', 'point-s', [0.5]], 
    ],
    'dds': [dd],
    'tit_plot': '',
    'flag_semilogy': True,
    'x_start': 0.5e5,
    'labx': 't[\omega_{ci}^{-1}]',
    'laby': '\overline{E}_r',
    'sel_legs1': 'woVN'
}
common.plot_vars_1d(oo_zonal_s1)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# *****************************************
# *** COMPARISON with GENE for CPS 2019 *** 
# *****************************************
reload()

oo_gene = {
    'dd_f0': dd_f0
}

mpr.comparison_with_GENE_CPS2019(dd, oo_gene)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# **********************
# *** TEST HISTOGRAM ***
# **********************
reload()

mpr.test_histogram()
# Out:
# <img src="data:image/png;base64,..." width="1000">
