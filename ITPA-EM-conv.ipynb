# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# %matplotlib notebook
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
run main_ITPA_EM_conv.py

# %%
# **************************
# *** ZONAL(t) max in s ***
# **************************
reload()

oo_zonal_t_max_s = {  
    'ovars': [
        ['zonal', 'vorbar'],
    ]*3,  
    'avrs': [
        ['ts', 'absmax-s'],
    ]*3,
#     'dds': [
#         dd_es, dd_m200, dd_m800
#     ],  
    'dds': [
#         dd_es, dd_m200, dd_m800_ns2
        dd_es, dd_m200, dd_m400
    ], 
    'labx': 't[\omega_{ci}^{-1}]',
    'tit_plot': '',
    'flag_semilogy': True
}
common.plot_vars_1d(oo_zonal_t_max_s)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# ****************************
# *** NONZONAL(t) max in s ***
# ****************************
reload()

oo_nonzonal_t_max_s = {  
    'ovars': [
        ['zonal', 'phibar'],
        ['zonal', 'phibar'],
        ['nonzonal', 'phinz-max-chi'],
        ['nonzonal', 'phinz-max-chi'],
    ],  
    'avrs': [
        ['ts', 'absmax-s'],
        ['ts', 'absmax-s'],
        ['ts', 'absmax-s'],
        ['ts', 'absmax-s']
    ],
    'dds': [
        dd_es, dd_em_m800_ni1_ne4
    ], 
    'labx': 't[\omega_{ci}^{-1}]',
    'tit_plot': '',
    'flag_semilogy': False
}
common.plot_vars_1d(oo_nonzonal_t_max_s)

# %%
xx = [['zonal', 'vorbar']]*3

# %%
xx
# Out:
# [['zonal', 'vorbar'], ['zonal', 'vorbar'], ['zonal', 'vorbar']]
