# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# %matplotlib notebook
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
run main_AUG20787.py

# %%
reload()
equ.q_prof(dd)
equ.nT_profs(dd)
equ.vp_profs(dd)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
reload()
zf.fft_gam_2d(dd, {'sel_norm': 'csa', 'sel_r': 's',
                'w_start': 0.25, 'w_end': 1, 
                's_start': 0.85, 's_end': 0.99, 'psi_start': 0.6, 'psi_end': 0.99,
                't_start': 0.2e5, 't_end': 1.47e5})
# zf.fft_gam_2d(dd, {'sel_norm': 'wci', 'sel_r': 's',
#                 'w_start': 0.5e-3, 'w_end': 2e-3, 
#                 's_start': 0.85, 's_end': 0.99, 'psi_start': 0.6, 'psi_end': 0.99,
#                 't_start': 0.2e5, 't_end': 1.47e5})
# zf.fft_gam_2d(dd, {'sel_norm': 'khz', 'sel_r': 's',
#                 'w_start': 5, 'w_end': 30, 
#                 's_start': 0.85, 's_end': 0.996, 'psi_start': 0.6, 'psi_end': 0.99,
#                 't_start': 0.2e5, 't_end': 1.47e5})
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
reload()
zf.time_evol_st(dd, {'s_start': 0.4, 's_end': 0.99, 't_start': 0.e5, 't_end': 1.9e5})
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
reload()
zf.efluxw_rad_2d('deuterium', dd, {'w_start': 0.5e-1, 'w_end': 1, 
                                   's_start': 0.8, 
                                   't_start': 2e4, 
                                   't_av_start': 2e4,
                                   'ns_av': 2, 
                                   's_av1_start': 0.8, 's_av1_end': 0.99, 
                                   's_av2_start': 0.8, 's_av2_end': 0.99})
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
reload()
zf.heat_vorticity('deuterium', dd, {'t_start': 1.5e5, 't_end': 2.e5,
                                    'ns_av': 2, 
                                    's_av1_heat_start':   0.6, 's_av1_heat_end':   1.0,
                                    's_av1_vorbar_start': 0.6, 's_av1_vorbar_end': 1.0,
                                    's_av2_heat_start':   0.3, 's_av2_heat_end':   0.6, 
                                    's_av2_vorbar_start': 0.6, 's_av2_vorbar_end': 1.0,})
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
B0 = 1.9
mi = 2*1.6726219e-27
e= 1.6e-19
wc = e*B0/mi
t_max = 13e3 * 2 / wc

# %%
t_max
# Out:
# 0.000286106377631579

# %%
reload()
path_profile_read = 'd:/Work-Projects/MyProgs/ORB_data/turbulence/AUG20787/adiab/init_profiles/'
path_profile_write = 'd:/Work-Projects/MyProgs/ORB_data/turbulence/AUG20787/adiab/profiles_with_vp/'
file_names = ['deuterium_profiles.dat']
work_profiles.build_vpp_profile(path_profile_read, path_profile_write, file_names)

# %%
reload()
# path_file = 'd:/Work-Projects/MyProgs/ORB_data/turbulence/AUG20787/adiab/init_profiles/'
# file_names = ['deuterium_profiles.dat', 'electrons_profiles.dat']

path_file = 'd:/Work-Projects/MyProgs/ORB_data/turbulence/AUG20787/adiab/profiles_with_vp/'
file_names = ['deuterium_profiles.dat']

work_profiles.plot_profiles(path_file, file_names)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
