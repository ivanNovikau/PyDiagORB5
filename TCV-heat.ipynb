# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# %matplotlib notebook
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
run main_TCV.py

# %%
dd120 = dict(dd)

# %%
dd80 = dict(dd)

# %%
dd40 = dict(dd)

# %%
reload()
equ.q_prof(dd)
equ.nT_profs(dd)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
# time evolution of the radial structure of the effective diffusion coefficient
reload()
transport.chi('deuterium', dd, {'t_start': 1e5, 's_start': 0.3})
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
# chi averaged in space or in time
reload()
oo_av_chi = {'ns_av': 2, 
             's_av1_start': 0.2, 's_av1_end': 0.6, 
             's_av2_start': 0.6, 's_av2_end': 1.0,
             't_av_start': 1e5, 't_av_end': 4e5}

# oo_av_chi = {'ns_av': 1, 
#              's_av1_start': 0.6, 's_av1_end': 1.0,
#              't_av_start': 1e5, 't_av_end': 4e5, 's_start': 0.3, 's_end': 1.0}

transport.chi_aver_st('deuterium', dd, oo_av_chi)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
reload()
transport.fft_chi('deuterium', dd, {'t_start': 5e4, 
                                    's_start': 0.3,
                                    'w_start': 0.5e-1, 'w_end': 1})
# Out:
# D:\Work-Projects\MyProgs\PyWorkScripts\PyDiagORB5\transport.py:84: RuntimeWarning:
#
# divide by zero encountered in true_divide
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-18f402961696> in <module>
#       2 transport.fft_chi('deuterium', dd, {'t_start': 5e4,
#       3                                     's_start': 0.3,
# ----> 4                                     'w_start': 0.5e-1, 'w_end': 1})
#
# D:\Work-Projects\MyProgs\PyWorkScripts\PyDiagORB5\transport.py in fft_chi(species_name, dd, oo)
#     101
#     102     # FFT
# --> 103     w, _, nw = ymath.w_for_fft(t)
#     104     w = w * 2 * np.pi
#     105     fft_rad_flux, _ = ymath.fft_y(rad_flux, nw, 0)
#
# AttributeError: module 'ymath' has no attribute 'w_for_fft'

# %%
reload()
transport.T('deuterium', dd, {'t_start': 2e4, 's_start': 0.3})
transport.n('deuterium', dd, {'t_start': 2e4, 's_start': 0.3})
transport.grad_T('deuterium', dd, {'t_start': 2e4, 's_start': 0.9})
transport.grad_n('deuterium', dd, {'t_start': 2e4, 's_start': 0.9})

# %%
# save data from n = 80
reload()
oo_save = {'ns_av': 2, 
             's_av1_start': 0.2, 's_av1_end': 0.6, 
             's_av2_start': 0.6, 's_av2_end': 1.0,
             't_av_start': 1e5, 't_av_end': 4e5,
             'project_name': 'n = 80',    # !!!
             'flag_save': True, 'save_name': 'chi'}
transport.chi_aver_st('deuterium', dd80, oo_save)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
# save data from n = 40
reload()
oo_save = {'ns_av': 2, 
             's_av1_start': 0.2, 's_av1_end': 0.6, 
             's_av2_start': 0.6, 's_av2_end': 1.0,
             't_av_start': 1e5, 't_av_end': 4e5,
             'project_name': 'n = 40',    # !!!
             'flag_save': True, 'save_name': 'chi'}
transport.chi_aver_st('deuterium', dd40, oo_save)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
# compare n80 vs n120
reload()
oo_load = {'ns_av': 2, 
             's_av1_start': 0.2, 's_av1_end': 0.6, 
             's_av2_start': 0.6, 's_av2_end': 1.0,
             't_av_start': 1e5, 't_av_end': 4e5,
             'project_name': 'n = 120',    # !!!
             'list_curves_load_avs': [dd80['saved_data']['chi-avs'] ],
             'list_curves_load_avt': [dd80['saved_data']['chi-avt'] ]
          }
transport.chi_aver_st('deuterium', dd120, oo_load)

# %%
# compare n80 vs n40
reload()
oo_load = {'ns_av': 2, 
             's_av1_start': 0.2, 's_av1_end': 0.6, 
             's_av2_start': 0.6, 's_av2_end': 1.0,
             't_av_start': 1e5, 't_av_end': 4e5,
             'project_name': 'n = 80',    # !!!
             'list_curves_load_avs': [dd40['saved_data']['chi-avs'] ],
             'list_curves_load_avt': [dd40['saved_data']['chi-avt'] ]
          }
transport.chi_aver_st('deuterium', dd80, oo_load)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
