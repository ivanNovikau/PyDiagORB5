# %%
# ***********************************************************
# SCAN ON EP LOCALISATION: DIRECT and MPR DIAGNOSTIC
# ***********************************************************
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# %matplotlib notebook
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
run main_NLED31213

# %%
print(0.25**(0.5))
print(0.35**(0.5))
print(0.45**(0.5))
print(0.55**(0.5))
# Out:
# 0.5
# 0.5916079783099616
# 0.6708203932499369
# 0.7416198487095663

# %%
# *******************
# *** PLOT: (t,s) ***
# *******************
reload()

npr = 2

oo_ts = {
    'ovars': [
        ['zonal', 'erbar'], 
    ] * npr,
    'avrs': [
        ['ts']
    ] * npr,
    'dds': [b045_f005_v9, b045_f005_v10],
#     'var_legs1': ['f = 0.01'],
#     'var_legs2': ['f = 0.05'],
#     'var_legs3': ['f = 0.0949'],
}

oo_ts.update({
#      't_start': 6e4,
#     't_end': 6.3e4,
#      's_start': 0.3, 's_end': 0.7,
})

common.plot_vars_2d(oo_ts)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
# ***********************
# *** PLOT: (t) at s1 ***
# ***********************
reload()

npr = 2
s1 = 0.67

oo_t_s1 = {
    'ovars': [
        ['zonal', 'erbar'],
    ]*npr,
    'avrs': [
        ['ts', 'point-s', [s1]],
    ]*npr,
    'dds': [b045_f005_v9, b045_f005_v10],
    'flag_semilogy': True,
    'stys': ['-', ':', ':', ':'],
    'labx': 't[\omega_{ci}^{-1}]',
#     'var_legs1': ['f = 0.05'],
#     'var_legs2': ['dt=10'],
#     'var_legs3': ['dt=20'],
    'x_start': 1e4, 
#     'x_end': 4.3e4,
}
common.plot_vars_1d(oo_t_s1)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# ****************************
# *** PLOT: (t) in [s1,s2] ***
# ****************************
reload()

npr = 1
s_int1 = [0.50, 0.80]

oo_t_ints1 = {
    'ovars': [
        ['zonal', 'erbar'],
    ]*npr,
    'avrs': [
        ['ts', 'mean-s', [s_int1]],
    ]*npr,
    'dds': [b045_f005_v9],
    'flag_semilogy': True,
    'stys': ['-', ':', ':', ':'],
    'labx': 't[\omega_{ci}^{-1}]',
#     'var_legs1': ['f = 0.05'],
#     'var_legs2': ['dt=10'],
#     'var_legs3': ['dt=20'],
#     'x_start': 1e4, 
#     'x_end': 4.3e4,
}
common.plot_vars_1d(oo_t_ints1)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# ***********************************************************
# *** DIRECT METHOD: FIND FRQUENCY and GAMMA (s1) ***
# ***********************************************************
reload()

# dd_current, s1 = dict(b045_f005_v9), 0.67
dd_current, s1 = dict(b045_f005_v10), 0.67

tmin, tmax = 6e4, 8.0e4
filt_global = None
filt_freq = None
min_n_peaks, threshold_w, threshold_g = 4, 0.1, 0.1
n_samples = 300    

oo_var = {
    'ovars': [['zonal', 'erbar']],
    'avrs': [['ts', 'point-s', [s1]]],
    'dds': [dd_current],
#     'sel_legs1': 'woPr',
}

oo_wg = {
    # BASIC
    't_work': [tmin, tmax], 
    'flag_two_stages': True,
#     'sel_norm': 'vt',
    # FILTERING
    'filt_global': filt_global, 
    'filt_freq': filt_freq,
    # STATISTICS
    'flag_stat':   True,
    'n_samples':   n_samples,
    'min_n_peaks': min_n_peaks,
    'threshold_w': threshold_w,
    'threshold_g': threshold_g,
}

oo_plot = {
#     't_plot': [0.15e4, 1.5e4],
    'flag_norm': True,
    'flag_semilogy': True
}

common.calc_wg(oo_var, oo_wg, oo_plot)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# --- NAIVE CALCULATION ---
# - GAMMA: ESTIMATION -
# prel. w[wci] = 6.746e-03
# g[wci] = 4.294e-05 +- 3.205e-06
# - GAMMA: NL FITTING -
# prel. w[wci] = 6.747e-03 +- 8.882e-07
# g[wci] = 4.297e-05 +- 8.827e-07
# - FREQUENCY: ESTIMATION -
# w[wci] = 6.746e-03
# (g_real - g_num)[wci] = -2.964e-08 +- 3.205e-06
# - FREQUENCY: NL FITTING -
# w[wci] = 6.746e-03 +- 9.180e-07
# (g_real - g_num)[wci] = -2.900e-07 +- 9.180e-07
# All chosen time intervals are unique.
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# --- STATISTICS ---
# number of frequency samples = 300
# number of rate samples = 227
# w[wci] = 6.749e-03+-8.695e-05
# g[wci] = 4.456e-05+-1.857e-05
# {'naive': {'w_est': 0.0067457510966652,
#   'g_est': 4.294445667867418e-05,
#   'w_adv': 0.0067464128449781285,
#   'g_adv': 4.29741009083842e-05},
#  'stat': {'w': 0.006748952393490302,
#   'err_w': 8.695084357478948e-05,
#   'g': 4.456073547880964e-05,
#   'err_g': 1.8569504707963185e-05}}

# %%
# ********************
# *** ES EGAM: MPR ***
# ********************
reload()

# species_name, flag_inv_peaks = 'total', True
species_name, flag_inv_peaks = 'deuterium', False
# species_name, flag_inv_peaks = 'fast', True

# dd_current, gam_w = dict(b045_f005_v9), 2.597e-03
dd_current, gam_w = dict(b045_f005_v10), 6.749e-03

tmin, tmax = 6.0e4, 8.0e4
n_samples, min_gam_n_periods = 100, 3
filt_je = None
filt_ef = None
filt_er = None

oo_vars = {
    'sel_species': species_name,
}

oo_wg = {
    't_work': [tmin, tmax],
    'flag_naive_t_peaks': True,
    'naive_n_periods': 4,
    'flag_inv_peaks': flag_inv_peaks,
    'gam-w': gam_w,  # normalization is always [wc]
    # calculate confidence intervals
    'flag_stat': True,
    'n_samples': n_samples,
    'min_gam_n_periods': min_gam_n_periods,
}

oo_plot = {
    't_plot': oo_wg['t_work'],
    'flag_norm': True,
    'flag_semilogy': True,
}

common.MPR_gamma(dd_current, oo_vars, oo_wg, oo_plot)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# All chosen time intervals are unique.
# <img src="data:image/png;base64,..." width="1000">
# velocity domain: \mu = [0.38, 112.36]$
# $ v_{\parallel} = [-14.8, 14.8]
# deuterium: Initial: g[wci] = 2.888e-07
# deuterium: Statistics: g[wci] = 5.478e-07+-5.999e-06

# %%
# ******************************
# *** ES EGAM: MPR: VELOCITY ***
# ******************************
reload()

species_name, flag_inv_peaks = 'deuterium', False
# species_name, flag_inv_peaks = 'fast', False

s1 = 0.67
# dd_current, gam_w, tit_proj = dict(b045_f005_v9),  2.597e-03, \
#     'ES\ EGAMb:\ \rho_{f} = 0.45,\ f_{fast} = 0.05,\ v_{parallel} = 9.0:\ '
dd_current, gam_w, tit_proj = dict(b045_f005_v10), 6.749e-03, \
    'ES\ EGAMb:\ \rho_{f} = 0.45,\ f_{fast} = 0.05,\ v_{parallel} = 10.0:\ '

t_int_start, t_int_end = 6e4, 8e4 
tmin, tmax = 6e4, 8e4  
n_samples, min_gam_n_periods = 100, 3

n_vpar_res = 6
mu_plot, vpar_plot = [], []
tit_vmu = [
    tit_proj + species_name + ':\ \langle\mathcal{P}\\rangle_{t}', 
    't = [{:0.3e}, {:0.3e}]'.format(t_int_start, t_int_end)
]

oo_wg = {
    # work and calculation time domain
    't_work': [tmin, tmax], 
    'flag_naive_t_peaks': False,
    'naive_n_periods': 4,
    'flag_inv_peaks': flag_inv_peaks,
    'gam-w': gam_w,  # normalization is always [wc]
    's1': s1,
    # calculate confidence intervals
    'flag_stat': False,
    'n_samples': n_samples,
    'min_gam_n_periods': min_gam_n_periods,
}
oo_plot = {
    't_plot': oo_wg['t_work'],
    'flag_norm': False,
    'flag_semilogy': True,
    'flag_pass_trap_cone': False,
    'mu_plot': mu_plot, 'vpar_plot': vpar_plot,
    'n_vpar_res' : n_vpar_res,
    'tit_vmu': tit_vmu,
}
oo_vars = {
    'sel_species': species_name,
    't_int': [t_int_start, t_int_end]
}

common.MPR_gamma_velocity_domains(dd_current, {}, oo_vars, oo_wg, oo_plot)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
from ip_projects import NLED_scans

# %%
# **********************
# *** SCAN ON F_PART ***
# **********************
mix.reload_module(NLED_scans)
NLED_scans.es_egam_fpart_scan_rho025({'sel_norm': 'khz', 'dd': b025_f001_v90})
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
import scipy.constants
import numpy as np

me = scipy.constants.electron_mass
eps0 = 8.854e-12
qe = scipy.constants.elementary_charge
w = 350e6  # Hz

n =(2*np.pi* w)**2 * eps0 * me / qe**2

print('n(1/m3) = {:0.3e}'.format(n))
# Out:
# n(1/m3) = 1.520e+15

# %%
n
# Out:
# 21239995585606.57

# %%
print('{:0.3e}'.format(me))
print('{:0.3e}'.format(eps0))
print('{:0.3e}'.format(qe))
# Out:
# 9.109e-31
# 8.854e-12
# 1.602e-19
