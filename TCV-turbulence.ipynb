# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# %matplotlib notebook
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
run main_TCV.py

# %%
reload()
oo_st_r =  {
    'opt_var': 'ernz_r',
    's_start': 0.5, 's_end': 0.995, 
    't_start': 0.1e5,
}
oo_st_chi =  {
    'opt_var': 'ernz_chi',
    's_start': 0.8, 's_end': 0.99, 
    't_start': 0.2e5,
}

itg.plot_st(dd, oo_st_chi)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
reload()
oo_avst =  {
    'opt_var': 'ernz_chi',
    't_start': 0.2e5, 
    's_start': 0.1, 's_end': 0.99,
    'ns_av': 2, 
    's_av1_start': 0.7, 's_av1_end': 0.8,
    's_av2_start': 0.9, 's_av2_end': 1.0,
    'nt_av': 1, 
    't_av1_start': 0.2e5, 't_av1_end': 1.75e5
    }

itg.plot_aver_st(dd, oo_avst)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
reload()
oo_fft = {
    'opt_var': 'ernz_chi',
    'sel_norm': 'csa', 'sel_r': 's',
    'w_start': 0.25, 'w_end': 1.2, 
    's_start': 0.8, 's_end': 0.99, 'psi_start': 0.6, 'psi_end': 0.99,
    't_start': 0.2e5, 't_end': 1.47e5,
    'flag_gao': True, 'flag_gk_fit': True, 'flag_aug20787': True
}

itg.plot_fft(dd, oo_fft)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
reload()
oo_avst =  {
    'opt_var': 'ernz_chi',
    'sel_norm': 'wc',
    'w_start': 0.1e-2, 'w_end': 0.25e-2,
#     'w_start': 0.01e-2, 'w_end': 0.5e-1,
    't_start': 0.2e5, 
    's_points': [0.9, 0.93, 0.95]
    }
itg.plot_fft_1d(dd, oo_avst)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# *** COMPARE AVERAGED SIGNALS ***
reload()

# --- chose signals ---
oo_nz_comp_avst =  {
    'opt_var_nz': 'ernz_r', 
    'var_type': 'zonal', 'opt_var': 'erbar',
    'flag_norm': True,
    }
oo_nz_comp_avst =  {
    'opt_var_nz': 'ernz_r', 
    'var_type': 'transport', 'opt_var': 'chi_norm', 'species_name': 'deuterium',
    'flag_norm': True,
    }

# --- define intervals ---
oo_nz_comp_avst.update({
    't_start': 0.2e5, 
    's_start': 0.1, 's_end': 0.99,
    })

# --- define parameters of averaging ---
oo_nz_comp_avst.update({
    'ns_av': 1, 
    's_av1_start': 0.9, 's_av1_end': 1.0,
    'nt_av': 1, 
    't_av1_start': 0.2e5, 't_av1_end': 1.75e5
    })

itg.compare_nz_var_aver_st(dd, oo_nz_comp_avst)
# Out:
# D:\Work-Projects\MyProgs\PyWorkScripts\PyDiagORB5\Species.py:94: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# D:\Work-Projects\MyProgs\PyWorkScripts\PyDiagORB5\Species.py:98: RuntimeWarning:
#
# invalid value encountered in log
#
# D:\Work-Projects\MyProgs\PyWorkScripts\PyDiagORB5\Species.py:100: RuntimeWarning:
#
# divide by zero encountered in log
#
# D:\Work-Projects\MyProgs\PyWorkScripts\PyDiagORB5\Species.py:100: RuntimeWarning:
#
# invalid value encountered in log
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
# *** COMPARE FFT 1D ***
reload()

# --- chose signals ---
oo_nz_comp_fft1d =  {
    'opt_var_nz': 'ernz_r', 
    'var_type': 'zonal', 'opt_var': 'erbar',
    'flag_norm': True,
    }
oo_nz_comp_fft1d =  {
    'opt_var_nz': 'ernz_r', 
    'var_type': 'transport', 'opt_var': 'chi_norm', 'species_name': 'deuterium',
    'flag_norm': True,
    }

# --- define intervals ---
oo_nz_comp_fft1d.update({
    't_start': 0.2e5, 
    })

# --- define parameters of averaging ---
oo_nz_comp_fft1d.update({
    'sel_norm': 'wc',
    'w_start': 0.1e-2, 'w_end': 0.25e-2,
    's_points': [],
    'flag_intervals': True, 'flag_aver': 'rms', 's_intervals': [[0.9, 0.95]]
    })

itg.compare_nz_var_fft_1d(dd, oo_nz_comp_fft1d)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# *** Find time delay between two signals ***
reload()

# --- chose signals ---
oo_corr =  {
    'opt_type1': 'nonzonal',  'opt_var1': 'ernz_r',  
    'opt_type2': 'transport', 'opt_var2': 'chi_norm', 'species_name2': 'deuterium',
    'flag_norm': True,
    }

# --- define intervals ---
oo_corr.update({
    't_start': 0.2e5, 
    })

# --- define parameters of averaging ---
oo_corr.update({
    'sel_norm': 'wc',
    'flag_aver1': 'mean', 's_interval1': [0.9, 0.95],
    'flag_aver2': 'mean', 's_interval2': [0.9, 0.95]
    })

common.correlation_two_vars(dd, oo_corr)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# t[\omega_c^{-1}] = 9.495e+02
# <img src="data:image/png;base64,..." width="1000">

# %%
import general

# --- Save data ---
reload()

# --- NL/muT1-mun5/n80-potsc ---
path_to_save = 'd:/Work-Projects/MyProgs/ORB_data/workspace-orb/PySpace/TCV-NL/n80-potsc/saved_data2.h5'

# to save Lx
var_name = 'Lx'
var_desc = 'plasma Lx'

# # to save phibar
# path_to_save = 'd:/Work-Projects/MyProgs/ORB_data/workspace-orb/PySpace/TCV-NL/n80-potsc/saved_data.h5'
# var_name = 'phibar'
# var_desc = 'zonal potential'

# # to save ernz_r
# var_name = 'ernz_r-chi-0.000'
# var_desc = 'non-zonal radial electric field at chi = 0'

# to save ernz_chi
var_name = 'ernz_chi-chi-0.000'
var_desc = 'non-zonal poloidal electric field at chi = 0'

# --- Saving ---
oo_save = {'path_to_save': path_to_save, 'var_name': var_name, 'var_desc': var_desc}
general.save_data_to_external_file(dd, oo_save)

# %%
reload()
itg.test_correlation(dd)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# t[\omega_c^{-1}] = 4.938e-02
# <img src="data:image/png;base64,..." width="1000">
