# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# %matplotlib notebook
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
run main_TCV

# %%
dd_work = dict(ant_itpa_n20)

# %%
# ************************
# *** RADIAL STRUCTURE ***
# ************************
reload()

t1 = 5e4
chi1 = 0.0

oo_rz = {
    'ovars': [
        ['nonzonal', 'potsc', t1],
    ],
    'avrs': [
        ['rz'],
    ],
    'dds': [dd_work],
}
common.plot_vars_2d(oo_rz)

oo_s = {
    'ovars': [
        ['nonzonal', 'potsc', chi1],
    ],
    'avrs': [
        ['ts', 'point-t', [t1]],
    ],
    'dds': [dd_work],
    'labx': 's',
}
common.plot_vars_1d(oo_s)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
# *******************************
# *** FIELD3D: along t at s1 ***
# *******************************
reload()

s1 = 0.60
chi1 = 0.0

oo_t_s1 = {
    'ovars': [
        ['nonzonal', 'potsc', chi1],
        ['fields3d', 'potsc', chi1],    
    ] ,
    'avrs': [
        ['ts', 'point-s', [s1]],
    ] * 2,
    'dds': [dd_work] * 2,
    'flag_semilogy': True,
    'labx': 't[\omega_{ci}^{-1}]',
    'stys': ['-', ':'],
}

common.plot_vars_1d(oo_t_s1)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# **********************************************************
# *** DIRECT METHOD: FIND FRQUENCY and GAMMA: POTSC (s1) ***
# **********************************************************
reload()

chi1 = 0.0
s1 = 0.60

tmin, tmax = 1e4, 5e4
filt_global = None
min_n_peaks, threshold_w, threshold_g = 2, 0.1, 0.1
n_samples = 300

# oo_var = {
#     'ovars': [['nonzonal', 'potsc', chi1]],
#     'avrs': [['ts', 'point-s', [s1]]],
#     'dds': [dd_work],
# }

oo_var = {
    'ovars': [['fields3d', 'potsc', chi1]],
    'avrs': [['ts', 'point-s', [s1]]],
    'dds': [dd_work],
}

oo_wg = {
    # BASIC
    't_work': [tmin, tmax], 
    'flag_two_stages': True,
    'sel_wg': 'wg-adv',
#     'sel_norm': 'vt',
    # FILTERING
    'filt_global': filt_global,
    # STATISTICS
    'flag_stat':   True,
    'n_samples':   n_samples,
    'min_n_peaks': min_n_peaks,
    'threshold_w': threshold_w,
    'threshold_g': threshold_g,
}

oo_plot = {
#     't_plot': [0.15e4, 1.5e4],
    'flag_norm': True,
    'flag_semilogy': True
}

common.calc_wg(oo_var, oo_wg, oo_plot)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# --- NAIVE CALCULATION ---
# - GAMMA: ESTIMATION -
# prel. w[wci] = 7.295e-04
# g[wci] = 3.029e-04 +- 6.829e-06
# - GAMMA: NL FITTING -
# prel. w[wci] = 7.346e-04 +- 2.750e-07
# g[wci] = 2.973e-04 +- 1.856e-07
# - FREQUENCY: ESTIMATION -
# w[wci] = 7.306e-04
# (g_real - g_num)[wci] = 2.540e-06 +- 4.227e-06
# - FREQUENCY: NL FITTING -
# w[wci] = 7.276e-04 +- 3.070e-07
# (g_real - g_num)[wci] = 4.701e-06 +- 3.076e-07
# All chosen time intervals are unique.
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# ...

# %%
3.7 * 20
# Out:
# 74.0

# %%
g[wci] = 1.891e-03 +- 1.204e-05
w[wci] = 8.004e-04 +- 5.297e-06
